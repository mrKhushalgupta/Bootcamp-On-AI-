# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\garvit jain\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\garvit jain\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\garvit jain\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\garvit jain\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\garvit jain\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\garvit jain\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Garvit
# [nltk_data]     Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Garvit
# [nltk_data]     Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Garvit
# [nltk_data]     Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Garvit Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Garvit
# [nltk_data]     Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Garvit Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
with open('Cricket.txt','r') as file:
    text = file.read()

# %%
sentences = sent_tokenize(text)
words = word_tokenize(text)

print("Sentences:", sentences)
print("Words:", words)
# Out:
# Sentences: ['Cricket is a thrilling sport that combines skill, strategy, and teamwork.', 'It is played with a bat and ball, enjoyed by millions around the world.', 'The game has a rich history, especially in countries like India and England.', 'Cricket fosters passion, uniting fans with its exciting matches and rivalries.', 'Cricket is a game of patience, skill, and precision.', 'From thrilling boundaries to nail-biting finishes, it keeps fans on the edge.', 'Its various formats offer something for every type of player and spectator.']
# Words: ['Cricket', 'is', 'a', 'thrilling', 'sport', 'that', 'combines', 'skill', ',', 'strategy', ',', 'and', 'teamwork', '.', 'It', 'is', 'played', 'with', 'a', 'bat', 'and', 'ball', ',', 'enjoyed', 'by', 'millions', 'around', 'the', 'world', '.', 'The', 'game', 'has', 'a', 'rich', 'history', ',', 'especially', 'in', 'countries', 'like', 'India', 'and', 'England', '.', 'Cricket', 'fosters', 'passion', ',', 'uniting', 'fans', 'with', 'its', 'exciting', 'matches', 'and', 'rivalries', '.', 'Cricket', 'is', 'a', 'game', 'of', 'patience', ',', 'skill', ',', 'and', 'precision', '.', 'From', 'thrilling', 'boundaries', 'to', 'nail-biting', 'finishes', ',', 'it', 'keeps', 'fans', 'on', 'the', 'edge', '.', 'Its', 'various', 'formats', 'offer', 'something', 'for', 'every', 'type', 'of', 'player', 'and', 'spectator', '.']

# %%
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]

print("Stemmed Words:", stemmed_words)
# Out:
# Stemmed Words: ['cricket', 'thrill', 'sport', 'combin', 'skill', 'strategi', 'teamwork', 'it', 'play', 'bat', 'ball', 'enjoy', 'million', 'around', 'world', 'the', 'game', 'rich', 'histori', 'especi', 'countri', 'like', 'india', 'england', 'cricket', 'foster', 'passion', 'unit', 'fan', 'excit', 'match', 'rivalri', 'cricket', 'game', 'patienc', 'skill', 'precis', 'from', 'thrill', 'boundari', 'finish', 'keep', 'fan', 'edg', 'it', 'variou', 'format', 'offer', 'someth', 'everi', 'type', 'player', 'spectat']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

print("Lemmatized Words:", lemmatized_words)
# Out:
# Lemmatized Words: ['Cricket', 'thrilling', 'sport', 'combine', 'skill', 'strategy', 'teamwork', 'It', 'played', 'bat', 'ball', 'enjoyed', 'million', 'around', 'world', 'The', 'game', 'rich', 'history', 'especially', 'country', 'like', 'India', 'England', 'Cricket', 'foster', 'passion', 'uniting', 'fan', 'exciting', 'match', 'rivalry', 'Cricket', 'game', 'patience', 'skill', 'precision', 'From', 'thrilling', 'boundary', 'finish', 'keep', 'fan', 'edge', 'Its', 'various', 'format', 'offer', 'something', 'every', 'type', 'player', 'spectator']

# %%
 ! pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\garvit jain\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\garvit jain\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\garvit jain\anaconda3\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\garvit jain\anaconda3\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\garvit jain\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\garvit jain\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\garvit jain\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\garvit jain\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\garvit jain\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\garvit jain\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\garvit jain\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\garvit jain\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from collections import Counter 

word_freq = Counter(words)
print("Word Frequencues:",word_freq)
# Out:
# Word Frequencues: Counter({',': 8, '.': 7, 'and': 6, 'a': 4, 'Cricket': 3, 'is': 3, 'thrilling': 2, 'skill': 2, 'with': 2, 'the': 2, 'game': 2, 'fans': 2, 'of': 2, 'sport': 1, 'that': 1, 'combines': 1, 'strategy': 1, 'teamwork': 1, 'It': 1, 'played': 1, 'bat': 1, 'ball': 1, 'enjoyed': 1, 'by': 1, 'millions': 1, 'around': 1, 'world': 1, 'The': 1, 'has': 1, 'rich': 1, 'history': 1, 'especially': 1, 'in': 1, 'countries': 1, 'like': 1, 'India': 1, 'England': 1, 'fosters': 1, 'passion': 1, 'uniting': 1, 'its': 1, 'exciting': 1, 'matches': 1, 'rivalries': 1, 'patience': 1, 'precision': 1, 'From': 1, 'boundaries': 1, 'to': 1, 'nail-biting': 1, 'finishes': 1, 'it': 1, 'keeps': 1, 'on': 1, 'edge': 1, 'Its': 1, 'various': 1, 'formats': 1, 'offer': 1, 'something': 1, 'for': 1, 'every': 1, 'type': 1, 'player': 1, 'spectator': 1})

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
